# %% [markdown]
# # Partie 2

# %% [markdown]
# # Nom et Prénoms :

# %% [markdown]
# N'DRI KOFFI Pierre Ezéchiel
# -

# %% [markdown]
# ## Base de données "diamonds"
# Disponible dans Seaborn et dans dossier "Datasets" du répertoire que ce notebook. Télécharger la base de données à partir du serveur cloud : <a href="https://iuaci.sharepoint.com/:x:/s/ExamenPythonM1GRAF/EV7pJJQS-Z5JnlDI3pr1snoBLIsZQBc9Hh65A0P7Bu2qBg?e=aboKMx">diamonds.csv</a> 👈

# %% [markdown]
# <h4 id="sommaire">Questions</h4>
# <ol>
#     <li><a href="#1">Charger le jeu de données "diamonds" et afficher les 1eres données</a></li>
#     <li><a href="#2">Changer les nom des colonnes et afficher</a></li>
#     <li><a href="#3">Statistiques descriptives</a></li>
#     <li><a href="#4">Vérifier les valeurs manquantes</a></li>
#     <li><a href="#5">Prix moyen des diamants</a></li>
#     <li><a href="#6">Diagramme à barres des diamants par qualité</a></li>
#     <li><a href="#7">Comparaison des diamants par qualité</a></li>
#     <li><a href="#8">Prix moyen des diamants par couleur
#     <li><a href="#9">Visualisation du prix en fonction de la clarté</a></li>
#     <li><a href="#10">Prix moyen par clarté</a></li>
#     <li><a href="#11">Affichage de la distribution des prix</a></li>
#     <li><a href="#12">Boîte à moustache du prix en fonction de la qualité</a></li>
#     <li><a href="#13">Statistiques des prix par qualité et couleur</a></li>
#     <li><a href="#14">Tableau croisé du prix moyen par qualité et couleur et visualisation</a></li>
#     <li><a href="#15">Distribution du poids des diamants ("carat")</a></li>
#     <li><a href="#16">Boîte à moustache du poids ("carat") en fonction de la qualité</a></li>
#     <li><a href="#17">Nuage de points du prix en fonction du poids et de la qualité</a></li>
#     <li><a href="#18">Corrélation entre les variables numériques</a></li>
#     <li><a href="#19">Visualisation de la heatmap des corrélations</a></li>
# </ol>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h4 id="1">1. Charger le jeu de données "diamonds" et afficher les 1eres données<a href="#sommaire">👆</a></h4>

# %%
#Dans la variable "df"
df = pd.read_csv("Datasets/diamonds.csv")
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# <h4 id="2">2. Remplacer les noms des colonnes et afficher le resultat<a href="#sommaire">👆</a></h4>

# %%
# remplacer les colonnes par :
# "cut":"qualité"
# "color":"couleur"
# "clarity":"clarté"
# "depth":"profondeur"
# "price":"prix"

df.rename(columns = {"cut":"qualité", "color":"couleur", "clarity":"clarté", "depth":"profondeur", "price":"prix"}, inplace = True)
df.head()
# Out:
#    carat  qualité couleur clarté  profondeur  table  prix     x     y     z
# 0   0.23    Ideal       E    SI2        61.5   55.0   326  3.95  3.98  2.43
# 1   0.21  Premium       E    SI1        59.8   61.0   326  3.89  3.84  2.31
# 2   0.23     Good       E    VS1        56.9   65.0   327  4.05  4.07  2.31
# 3   0.29  Premium       I    VS2        62.4   58.0   334  4.20  4.23  2.63
# 4   0.31     Good       J    SI2        63.3   58.0   335  4.34  4.35  2.75

# %% [markdown]
# <h4 id="3">3. Statistique descriptive<a href="#sommaire">👆</a></h4>

# %%
df.describe()
# Out:
#               carat    profondeur         table          prix             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# <h4 id="4">4. Valeurs manquantes<a href="#sommaire">👆</a></h4>

# %%
df.isnull().sum()
# Out:
# carat         0
# qualité       0
# couleur       0
# clarté        0
# profondeur    0
# table         0
# prix          0
# x             0
# y             0
# z             0
# dtype: int64

# %% [markdown]
# <h4 id="5">5. Prix moyen des diamants<a href="#sommaire">👆</a></h4>

# %%
# Calcul du Prix moyen des diamants
df["prix"].mean()
# Out:
# 3932.799721913237

# %% [markdown]
# <h4 id="6">6. Diagramme à barres de la distribution des diamants par qualité<a href="#sommaire">👆</a></h4>

# %%
# Nombre de diamant par qualité
df["qualité"].value_counts()
# Out:
# qualité
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
# Diagramme à barres de la distribution des diamants par qualité
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.countplot(df, x ="qualité")
plt.title("Distribution des diamants par qualité")
plt.xlabel('Qualité')
plt.ylabel('Nombre de diamants')
plt.show()

# %% [markdown]
# <h4 id="7">7. Comparaison du prix moyen des diamants par qualité <a href="#sommaire">👆</a></h4>

# %%
# Calcul du prix moyen par qualité
df.groupby("qualité")[["prix"]].mean()
# Out:
#                   prix
# qualité
# Fair       4358.757764
# Good       3928.864452
# Ideal      3457.541970
# Premium    4584.257704
# Very Good  3981.759891

# %%
# Afficher le graphique du prix moyen par qualité (barplot)
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.barplot(df, x = "qualité", y = "prix")
plt.title("Comparaison du prix moyen de diamant par qualité")
plt.xlabel('Qualité')
plt.ylabel('Prix')
plt.show()

# %% [markdown]
# <h4 id="8">8. Prix moyen des diamants par couleur<a href="#sommaire">👆</a></h4>

# %%
# Avec la courbe de densité (histplot)
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.histplot(df, x ="prix", hue ="couleur", kde=True, multiple='stack')
plt.title("Distribution du prix moyen de diamants par couleur")
plt.xlabel("prix de diamants")
plt.ylabel("Effectif")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <h4 id="9">9. Visualisation du prix en fonction de la clarté<a href="#sommaire">👆</a></h4>

# %%
# Visualisation du prix en fonction de la clarté
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.barplot(df, x ="clarté", y ="prix")
plt.title("Visualisation du prix en fonction de la clarté")
plt.xlabel('Clarté')
plt.ylabel('Prix')
plt.show()

# %% [markdown]
# <h4 id="10">10. Prix moyen par clarté<a href="#sommaire">👆</a></h4>

# %%
# Prix moyen des diamants par clarté
df.groupby("clarté")["prix"].mean()
# Out:
# clarté
# I1      3924.168691
# IF      2864.839106
# SI1     3996.001148
# SI2     5063.028606
# VS1     3839.455391
# VS2     3924.989395
# VVS1    2523.114637
# VVS2    3283.737071
# Name: prix, dtype: float64

# %% [markdown]
# <h4 id="11">11. Affichage de la distribution des prix<a href="#sommaire">👆</a></h4>

# %%
# Affichage de la distribution des prix
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.histplot(df["prix"], kde=True)
plt.title("Distribution du prix moyen de diamants")
plt.xlabel("prix")
plt.ylabel("Nombres de diamants")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <h4 id="12">12. Boxplot du prix en fonction de la qualité<a href="#sommaire">👆</a></h4>

# %%
# Boxplot des prix en fonction de la qualité
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.boxplot(df, y ="prix", x ="qualité")
plt.title("Boxplot des prix en fonction de la qualité")
plt.ylabel("Prix")
plt.xlabel("Qualité")
plt.show()

# %% [markdown]
# <h4 id="13">13. Statistiques des prix par qualité et couleur<a href="#sommaire">👆</a></h4>

# %%
# Statistiques des prix par qualité et couleur
df.groupby(["qualité", "couleur"])["prix"].describe()
# Out:
#                     count         mean          std    min      25%     50%  \
# qualité   couleur
# Fair      D         163.0  4291.061350  3286.114238  536.0  2204.50  3730.0
#           E         224.0  3682.312500  2976.651645  337.0  1589.50  2956.0
#           F         312.0  3827.003205  3223.302685  496.0  1641.75  3035.0
#           G         314.0  4239.254777  3609.644379  369.0  1985.00  3057.0
#           H         303.0  5135.683168  3886.481847  659.0  2457.50  3816.0
#           I         175.0  4685.445714  3730.271132  735.0  2324.00  3246.0
#           J         119.0  4975.655462  4050.458933  416.0  2313.00  3302.0
# Good      D         662.0  3405.382175  3175.148710  361.0   957.25  2728.5
#           E         933.0  3423.644159  3330.702061  327.0   969.00  2420.0
#           F         909.0  3495.750275  3202.411187  357.0  1214.00  2647.0
#           G         871.0  4123.482204  3702.504718  394.0  1244.50  3340.0
# ...

# %% [markdown]
# <h4 id="14">14. Tableau croisé du prix moyen par qualité et couleur et visualisation<a href="#sommaire">👆</a></h4>

# %%
# Tableau croisé du prix moyen par qualité et couleur
tabCroise = pd.pivot_table(df, values='prix', index='couleur', columns='qualité', aggfunc='mean')
tabCroise
# Out:
# qualité         Fair         Good        Ideal      Premium    Very Good
# couleur
# D        4291.061350  3405.382175  2629.094566  3631.292576  3470.467284
# E        3682.312500  3423.644159  2597.550090  3538.914420  3214.652083
# F        3827.003205  3495.750275  3374.939362  4324.890176  3778.820240
# G        4239.254777  4123.482204  3720.706388  4500.742134  3872.753806
# H        5135.683168  4276.254986  3889.334831  5216.706780  4535.390351
# I        4685.445714  5078.532567  4451.970377  5946.180672  5255.879568
# J        4975.655462  4574.172638  4918.186384  6294.591584  5103.513274

# %%
# Heatmap du tableau croisé
sns.heatmap(tabCroise, annot=True, fmt=".2f")
plt.title('Tableau croisé du prix mmoyen par qualité et par couleur')
plt.show()

# %% [markdown]
# <h4 id="15">15. Distribution du poids des diamants ("carat")<a href="#sommaire">👆</a></h4>

# %%
# Distribution du poids des diamants ("carat")
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.histplot(df["carat"], kde=True, bins=20)
plt.title("Distribution du poids des diamants")
plt.xlabel("poids")
plt.ylabel("Nombres de diamants")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <h4 id="16">16. Boxplot du poids ("carat") en fonction de la qualité<a href="#sommaire">👆</a></h4>

# %%
# Boxplot du poids ("carat") en fonction de la qualité
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.boxplot(df, y ="carat", x ="qualité")
plt.title("Boxplot du poids (carat) en fonction de la qualité")
plt.ylabel("Poids")
plt.xlabel("Qualité")
plt.show()

# %% [markdown]
# <h4 id="17">17. Nuage de points du prix en fonction du poids et de la qualité<a href="#sommaire">👆</a></h4>

# %%
# Nuage de points du prix en fonction du poids et de la qualité
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.scatterplot(df, x="prix", y="carat", hue ="qualité")
plt.title("Nuage de points du prix en fonction du poids")
plt.xlabel("Prix")
plt.ylabel("Poids")
plt.show()

# %% [markdown]
# <h4 id="18">18. Corrélation entre les variables numériques<a href="#sommaire">👆</a></h4>

# %%
# Corrélation entre les variables numériques
df.drop(df.select_dtypes(include=['object']).columns, axis=1).corr()
# Out:
#                carat  profondeur     table      prix         x         y  \
# carat       1.000000    0.028224  0.181618  0.921591  0.975094  0.951722
# profondeur  0.028224    1.000000 -0.295779 -0.010647 -0.025289 -0.029341
# table       0.181618   -0.295779  1.000000  0.127134  0.195344  0.183760
# prix        0.921591   -0.010647  0.127134  1.000000  0.884435  0.865421
# x           0.975094   -0.025289  0.195344  0.884435  1.000000  0.974701
# y           0.951722   -0.029341  0.183760  0.865421  0.974701  1.000000
# z           0.953387    0.094924  0.150929  0.861249  0.970772  0.952006
#
#                    z
# carat       0.953387
# profondeur  0.094924
# table       0.150929
# prix        0.861249
# x           0.970772
# y           0.952006
# z           1.000000

# %% [markdown]
# <h4 id="19">19. Visualisation de la heatmap des corrélations<a href="#sommaire">👆</a></h4>

# %%
# Heatmap des corrélations
sns.heatmap(df.drop(df.select_dtypes(include=['object']).columns, axis=1).corr())
plt.title("Carte de chaleur de la matrice de corrélation")
plt.show()
