# %% [markdown]
# # Partie 3

# %% [markdown]
# # Nom et Prénoms :

# %% [markdown]
# N'DRI KOFFI Pierre Ezéchiel
# -

# %% [markdown]
# ## Base de données "notes"
# Disponible dans le même répertoire que ce notebook. Télécharger la base de données à partir du serveur : <a href="https://iuaci.sharepoint.com/:x:/s/ExamenPythonM1GRAF/EcUiYQ5u-LVNo7uwO0-fIwMBCYUjdi8Mq1M0pEEA0u0vWw?e=ZVqtCk">notes_IUA.csv</a> 👈

# %% [markdown]
# <h4 id="sommaire">Questions</h4>
# <ol>
#     <li><a href="#1">Charger le jeu de données "note_IUA" </a></li>
#     <li><a href="#2">Infos sur le dataset : types de variables, valeurs manquantes, etc. </a></li>
#     <li><a href="#3">Statistiques descriptives pour les notes et l'âge</a></li>
#     <li><a href="#4">Vérifier les valeurs manquantes</a></li>
#     <li><a href="#5">Distribution de l'âge des étudiants</a></li>
#     <li><a href="#6">Diagramme à barres du nombre d'étudiants par ville</a></li>
#     <li><a href="#7">Création d'une colonne "moyenne" pour les notes</a></li>
#     <li><a href="#8">Comparaison des moyennes de notes par ville de résidence</a></li>
#     <li><a href="#9">Boxplot des notes en fonction de la ville de naissance</a></li>
#     <li><a href="#10">Statistiques de l'âge par ville de résidence</a></li>
#     <li><a href="#11">Tableau croisé des villes et des notes moyennes</a></li>
#     <li><a href="#12">Boxplot des âges des étudiants en fonction de la ville de naissance</a></li>
#     <li><a href="#13">Nuage de points de l'âge et de la moyenne des notes</a></li>
#     <li><a href="#14">Corrélation entre les notes et l'âge</a></li>
#     <li><a href="#15">Distribution des moyennes de notes par ville de naissance</a></li>
#     <li><a href="#16">Boxplot des notes par ville de résidence</a></li>
#     <li><a href="#17">Nuage de points des notes en fonction de l'âge</a></li>
#     <li><a href="#18">Quels sont les meilleurs étudiants selon le type de maison ?</a></li>
#
# </ol>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h4 id="1">1. Charger le jeu de données "notes_IUA" et afficher les 1eres données<a href="#sommaire">👆</a></h4>

# %%
#Dans la variable "df"
df = pd.read_csv("Datasets/note_IUA.csv", sep=";")
df.head()
# Out:
#   Matricule                             Nom         Ville Ville_Naissance  \
# 0   IUA_001  ABOU GRAN CHRIST YVANN JEREMIE        Bouaké             Man
# 1   IUA_002  AKINOCHO MAURINE EMERAUDE TINU       Toumodi         Korhogo
# 2   IUA_003   ANOH ASSIBLA ANNE MARIE SUZAN        Soubré         Séguéla
# 3   IUA_004             Anougba Tehoua Yvan  Agnibilékrou             Man
# 4   IUA_005             BILE ASSOBA HERMANN       Korhogo         Mankono
#
#          Maison  Age  Note_1  Note_2  Note_3  Note_4
# 0         Villa   19       0       4      11       7
# 1  Cour-commune   17       2       7       7       4
# 2  Cour-commune   20      13       3       9      10
# 3       Chateau   23      10      12      16      14
# 4  Cour-commune   24       7       7       2       3

# %% [markdown]
# <h4 id="2">2. Infos sur le dataset : types de variables, valeurs manquantes, etc.<a href="#sommaire">👆</a></h4>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Matricule        1000 non-null   object
#  1   Nom              1000 non-null   object
#  2   Ville            1000 non-null   object
#  3   Ville_Naissance  1000 non-null   object
#  4   Maison           1000 non-null   object
#  5   Age              1000 non-null   int64
#  6   Note_1           1000 non-null   int64
#  7   Note_2           1000 non-null   int64
#  8   Note_3           1000 non-null   int64
#  9   Note_4           1000 non-null   int64
# dtypes: int64(5), object(5)
# memory usage: 78.3+ KB

# %% [markdown]
# <h4 id="3">3. Statistique descriptive<a href="#sommaire">👆</a></h4>

# %%
df.describe()
# Out:
#                Age       Note_1       Note_2      Note_3       Note_4
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean     22.359000     9.843000     9.315000     9.36100     9.431000
# std       3.985725     5.731248     5.836766     5.69026     5.816792
# min      16.000000     0.000000     0.000000     0.00000     0.000000
# 25%      19.000000     5.000000     4.000000     4.75000     4.000000
# 50%      22.000000    10.000000     9.000000     9.00000     9.000000
# 75%      26.000000    15.000000    14.000000    14.00000    14.250000
# max      29.000000    19.000000    19.000000    19.00000    19.000000

# %% [markdown]
# <h4 id="4">4. Valeurs manquantes<a href="#sommaire">👆</a></h4>

# %%
df.isnull().sum()
# Out:
# Matricule          0
# Nom                0
# Ville              0
# Ville_Naissance    0
# Maison             0
# Age                0
# Note_1             0
# Note_2             0
# Note_3             0
# Note_4             0
# dtype: int64

# %% [markdown]
# <h4 id="5">5. Distribution de l'âge des étudiants<a href="#sommaire">👆</a></h4>

# %%
# Distribution de l'âge des étudiants
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.histplot(df["Age"], kde=True)
plt.title("Distribution de l'âge des étudiants")
plt.xlabel("Age")
plt.ylabel("Nombre d'étudiant")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <h4 id="6">6. Diagramme à barres du nombre d'étudiants par ville<a href="#sommaire">👆</a></h4>

# %%
# Nombre d'étudiant par ville
df["Ville"].value_counts()
# Out:
# Ville
# Toumodi           49
# Ferkessédougou    47
# Abengourou        47
# Agboville         46
# Man               45
# Korhogo           45
# Issia             44
# Mankono           43
# Daloa             42
# Danané            41
# Yamoussoukro      41
# Soubré            41
# Lakota            40
# Abidjan           40
# Bouaké            39
# Tiassalé          38
# Boundiali         37
# Odienné           37
# Bondoukou         36
# Séguéla           36
# Divo              36
# Agnibilékrou      35
# San-Pédro         33
# Gagnoa            33
# Bouna             29
# Name: count, dtype: int64

# %%
# Diagramme à barres de la distribution des étudiants par ville
plt.figure(figsize=(23, 8))
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.countplot(df, x ="Ville")
plt.title("Nombre d'étudiants par ville")
plt.xlabel('Ville')
plt.ylabel("Nombre d'étudiants")
plt.show()

# %% [markdown]
# <h4 id="7">7. Création d'une colonne "moyenne" pour les notes Distribution de la moyenne des notes <a href="#sommaire">👆</a></h4>

# %%
# Moyenne des notes pour chaque étudiant
# La colonne doit être nommée "Moyenne"
df["Moyenne"] = (df["Note_1"] + df["Note_2"] + df["Note_3"] + df["Note_4"]) / 4
df.head()
# Out:
#   Matricule                             Nom         Ville Ville_Naissance  \
# 0   IUA_001  ABOU GRAN CHRIST YVANN JEREMIE        Bouaké             Man
# 1   IUA_002  AKINOCHO MAURINE EMERAUDE TINU       Toumodi         Korhogo
# 2   IUA_003   ANOH ASSIBLA ANNE MARIE SUZAN        Soubré         Séguéla
# 3   IUA_004             Anougba Tehoua Yvan  Agnibilékrou             Man
# 4   IUA_005             BILE ASSOBA HERMANN       Korhogo         Mankono
#
#          Maison  Age  Note_1  Note_2  Note_3  Note_4  Moyenne
# 0         Villa   19       0       4      11       7     5.50
# 1  Cour-commune   17       2       7       7       4     5.00
# 2  Cour-commune   20      13       3       9      10     8.75
# 3       Chateau   23      10      12      16      14    13.00
# 4  Cour-commune   24       7       7       2       3     4.75

# %%
# Afficher la distribution
sns.set_style("darkgrid", {'grid.color':'grey', 'grid.linestyle': '--'})
sns.histplot(df["Moyenne"],kde=True)
plt.title("Distribution des moyennes")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <h4 id="8">8. Comparaison des moyennes de notes par ville de résidence<a href="#sommaire">👆</a></h4>

# %%
# Moyenne des notes par ville
plt.figure(figsize=(23, 8))
sns.boxplot(df, x='Ville', y='Moyenne') 
plt.title('Comparaison des moyennes de notes par ville de résidence') 
plt.xlabel('Ville de résidence') 
plt.ylabel('Moyenne des notes') 
plt.show()

# %% [markdown]
# <h4 id="9">9. Boxplot des notes en fonction de la ville de naissance<a href="#sommaire">👆</a></h4>

# %%
# Boxplot des notes par ville de naissance
plt.figure(figsize=(23, 6))
sns.boxplot(df, x='Ville_Naissance', y='Moyenne')
plt.title("Boxplot des notes par ville de naissance")
plt.xlabel("Ville de naissance")
plt.ylabel("Moyenne des notes")
plt.show()

# %% [markdown]
# <h4 id="10">10. Statistiques de l'âge par ville de résidence<a href="#sommaire">👆</a></h4>

# %%
# Statistiques de l'âge par ville de résidence
print("Statistiques de l'âge par ville de résidence :")
df.groupby('Ville')['Age'].describe()
# Out:
# Statistiques de l'âge par ville de résidence :
#                 count       mean       std   min    25%   50%    75%   max
# Ville
# Abengourou       47.0  21.702128  3.611063  16.0  19.00  21.0  25.00  29.0
# Abidjan          40.0  22.450000  3.980401  16.0  19.00  22.0  26.00  29.0
# Agboville        46.0  22.478261  4.440916  16.0  18.00  22.0  27.00  29.0
# Agnibilékrou     35.0  22.342857  4.317835  16.0  19.00  22.0  26.50  29.0
# Bondoukou        36.0  23.055556  3.868883  16.0  20.00  23.5  26.00  29.0
# Bouaké           39.0  21.435897  4.393745  16.0  17.50  21.0  26.00  29.0
# Bouna            29.0  22.000000  4.123106  17.0  18.00  21.0  25.00  29.0
# Boundiali        37.0  21.810811  4.293651  16.0  18.00  21.0  26.00  29.0
# Daloa            42.0  22.261905  4.225703  16.0  18.25  22.5  25.00  29.0
# Danané           41.0  22.365854  3.733337  16.0  19.00  23.0  25.00  29.0
# Divo             36.0  23.027778  4.286098  17.0  19.00  22.5  27.00  29.0
# ...

# %% [markdown]
# <h4 id="11">11. Tableau croisé des villes et des notes moyennes<a href="#sommaire">👆</a></h4>

# %%
# Tableau croisé de la ville et moyenne des notes
print("Tableau croisé des villes et des notes moyennes:")
tabCroise = df.pivot_table(values='Moyenne', index='Ville', columns='Ville_Naissance', aggfunc='mean')
tabCroise
# Out:
# Tableau croisé des villes et des notes moyennes:
# Ville_Naissance  Abengourou    Abidjan  Agboville  Agnibilékrou  Bondoukou  \
# Ville
# Abengourou         8.750000   8.250000   8.800000     12.250000   8.625000
# Abidjan            8.375000  10.375000        NaN     10.875000   7.125000
# Agboville               NaN        NaN   9.250000      8.125000        NaN
# Agnibilékrou       9.125000  10.500000        NaN      9.333333  11.000000
# Bondoukou         10.250000   9.833333   8.750000      9.666667   8.750000
# Bouaké             9.000000   7.625000   9.500000      9.750000  13.750000
# Bouna             10.750000   7.750000   8.250000     11.250000        NaN
# Boundiali          5.625000  10.000000   5.000000     13.000000   5.500000
# Daloa              9.333333  11.250000  13.750000           NaN  12.125000
# Danané                  NaN   8.875000  13.750000     10.750000  15.000000
# Divo               7.875000   8.000000   6.875000           NaN   4.000000
# ...

# %%
# Heatmap du tableau croisé
plt.figure(figsize=(10, 6))
sns.heatmap(tabCroise , annot=True, fmt=".2f")
plt.title('Heatmap du tableau croisé des villes et des notes moyennes')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# <h4 id="12">12. Boxplot des âges des étudiants en fonction de la ville de naissance<a href="#sommaire">👆</a></h4>

# %%
# Boxplot des âges par ville de naissance
plt.figure(figsize=(23, 8)) 
sns.boxplot(df, x='Ville_Naissance', y='Age') 
plt.title('Boxplot des âges des étudiants en fonction de la ville de naissance') 
plt.xlabel('Ville de naissance') 
plt.ylabel('Âge') 
plt.show()

# %% [markdown]
# <h4 id="13">13. Nuage de points de l'âge et de la moyenne des notes<a href="#sommaire">👆</a></h4>

# %%
# Nuage de points âge et moyenne des notes
plt.figure(figsize=(10, 6)) 
sns.scatterplot(df, x='Age', y='Moyenne') 
plt.title('Nuage de points de l\'âge et de la moyenne des notes') 
plt.xlabel('Âge') 
plt.ylabel('Moyenne des notes') 
plt.show()

# %% [markdown]
# <h4 id="14">14. Corrélation entre les notes et l'âge<a href="#sommaire">👆</a></h4>

# %%
# Corrélation entre les notes et l'âge
df[['Note_1', 'Note_2', 'Note_3', 'Note_4', 'Age']].corr()
# Out:
#           Note_1    Note_2    Note_3    Note_4       Age
# Note_1  1.000000  0.019913 -0.065419  0.019147 -0.029914
# Note_2  0.019913  1.000000  0.009954  0.010709  0.061226
# Note_3 -0.065419  0.009954  1.000000  0.024085 -0.001880
# Note_4  0.019147  0.010709  0.024085  1.000000  0.001998
# Age    -0.029914  0.061226 -0.001880  0.001998  1.000000

# %%
# Heatmap du tableau croisé
sns.heatmap(df[['Note_1', 'Note_2', 'Note_3', 'Note_4', 'Age']].corr(), annot=True, fmt=".2f")
plt.title("Heatmap du tableau croisé des notes et l'âge")
plt.show()

# %% [markdown]
# <h4 id="15">15. Distribution des moyennes de notes par ville de naissance<a href="#sommaire">👆</a></h4>

# %%
# Distribution des moyennes par ville de naissance
plt.figure(figsize=(23, 8))
sns.histplot(df, x='Moyenne', hue='Ville_Naissance', multiple='stack') 
plt.title('Distribution des moyennes de notes par ville de naissance') 
plt.xlabel('Moyenne des notes') 
plt.ylabel('Fréquence') 
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <h4 id="16">16. Boxplot des notes par ville de résidence<a href="#sommaire">👆</a></h4>

# %%
# Boxplot des notes par ville de résidence
plt.figure(figsize=(23, 8)) 
sns.boxplot(df, x='Ville', y='Moyenne') 
plt.title('Boxplot des notes par ville de résidence') 
plt.xlabel('Ville de résidence') 
plt.ylabel('Moyenne des notes') 
plt.show()

# %% [markdown]
# <h4 id="17">17. Nuage de points des notes en fonction de l'âge<a href="#sommaire">👆</a></h4>

# %%
# Nuage de points des notes en fonction de l'âge
plt.figure(figsize=(15, 8)) 
sns.scatterplot(df, x='Age', y='Moyenne', hue='Ville') 
plt.title("Nuage de points des notes en fonction de l'âge") 
plt.xlabel('Âge') 
plt.ylabel('Moyenne des notes')
plt.legend(title='Appréciation', bbox_to_anchor=(1.05, 1), loc='upper left') 
plt.show()

# %% [markdown]
# <h4 id="18">18. Quels sont les meilleurs étudiants selon le type de maison ?<a href="#sommaire">👆</a></h4>

# %%
# Créons d'une nouvelle colonne 'Appréciation' pour les notes

def attribuer_appreciation(moyenne):
    if moyenne == 0 or moyenne ==1:
        return "Nul"
    elif moyenne <= 8:
        return "Insuffisant"
    elif moyenne <= 10:
        return "Passable"
    elif moyenne <= 12:
        return "Assez bien"
    elif moyenne <= 14:
        return "Bien"
    elif moyenne <= 18:
        return "Très bien"

df['Appréciation'] = df['Moyenne'].apply(attribuer_appreciation)
df.head()
# Out:
#   Matricule                             Nom         Ville Ville_Naissance  \
# 0   IUA_001  ABOU GRAN CHRIST YVANN JEREMIE        Bouaké             Man
# 1   IUA_002  AKINOCHO MAURINE EMERAUDE TINU       Toumodi         Korhogo
# 2   IUA_003   ANOH ASSIBLA ANNE MARIE SUZAN        Soubré         Séguéla
# 3   IUA_004             Anougba Tehoua Yvan  Agnibilékrou             Man
# 4   IUA_005             BILE ASSOBA HERMANN       Korhogo         Mankono
#
#          Maison  Age  Note_1  Note_2  Note_3  Note_4  Moyenne Appréciation
# 0         Villa   19       0       4      11       7     5.50  Insuffisant
# 1  Cour-commune   17       2       7       7       4     5.00  Insuffisant
# 2  Cour-commune   20      13       3       9      10     8.75     Passable
# 3       Chateau   23      10      12      16      14    13.00         Bien
# 4  Cour-commune   24       7       7       2       3     4.75  Insuffisant

# %%
# Tableau croisé pour calculer la distribution des appréciations par type de maison
# Avec pour paramètre margins=False
pd.crosstab(df['Maison'], df['Appréciation'], margins=False)
# Out:
# Appréciation  Assez bien  Bien  Insuffisant  Nul  Passable  Très bien
# Maison
# Chateau               46    65           12    0         0         59
# Cour-commune          35     5          267    1       212          0
# Villa                140    59           63    0        34          1

# %%
# Créer une heatmap pour visualiser la relation entre Le type de Maison et l'Appréciation
# Avec cmap="YlGnBu", annot=True, fmt="d" comme paramètres
plt.figure(figsize=(10, 6)) 
sns.heatmap(pd.crosstab(df['Maison'], df['Appréciation'], margins=False), annot=True, fmt="d") 
plt.title("Relation entre le type de maison et l'appréciation") 
plt.xlabel('Appréciation') 
plt.ylabel('Type de maison') 
plt.show()

# %%
# Créer un barplot pour visualiser la distribution des appréciations par type de maison
appreciation = df.groupby('Maison')['Appréciation'].value_counts(normalize=True).unstack().fillna(0) 
appreciation.plot(kind='bar', stacked=True, figsize=(10, 6)) 
plt.title('Distribution des appréciations par type de maison') 
plt.xlabel('Type de maison') 
plt.ylabel("Proportion d'étudiants") 
plt.legend(title='Appréciation', bbox_to_anchor=(1.05, 1), loc='upper left') 
plt.show()

# %%
# Conclusion
print("La heatmap montre la relation entre le type de maison et les appréciations des étudiants, tandis que le barplot met en évidence la distribution des appréciations par type de maison.\nCela peut révéler des tendances intéressantes, par exemple si certains types de logement sont associés à des performances académiques supérieures. Les résultats peuvent aider à comprendre l'impact du cadre de vie sur la réussite scolaire.")
# Out:
# La heatmap montre la relation entre le type de maison et les appréciations des étudiants, tandis que le barplot met en évidence la distribution des appréciations par type de maison.
# Cela peut révéler des tendances intéressantes, par exemple si certains types de logement sont associés à des performances académiques supérieures. Les résultats peuvent aider à comprendre l'impact du cadre de vie sur la réussite scolaire.
